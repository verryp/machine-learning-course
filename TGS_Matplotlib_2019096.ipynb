# %% [markdown]
# <a href="https://colab.research.google.com/github/vrry/learning-phyton/blob/master/TGS_Matplotlib_2019096.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The Dataset: Gapminder Life Expectancy Year <a id="2"></a>
#
# Dataset Source : https://data.world/brianray/gapminder-life-expectancy-year

# %%
import numpy as np 
import pandas as pd

# %%
df_life = pd.read_csv('https://query.data.world/s/gxftiborizpamohkrl4p6nmbm26hcs')

print ('Data read into a pandas dataframe!')
# Out:
# Data read into a pandas dataframe!

# %%
df_life.head()
# Out:
#          Life expectancy   1800   1801   1802  ...  2013  2014  2015   2016
# 0               Abkhazia    NaN    NaN    NaN  ...   NaN   NaN   NaN    NaN
# 1            Afghanistan  28.21  28.20  28.19  ...  54.8  54.9  53.8  52.72
# 2  Akrotiri and Dhekelia    NaN    NaN    NaN  ...   NaN   NaN   NaN    NaN
# 3                Albania  35.40  35.40  35.40  ...  77.7  77.9  78.0  78.10
# 4                Algeria  28.82  28.82  28.82  ...  76.3  76.3  76.4  76.50
#
# [5 rows x 218 columns]

# %%
df_life.tail()
# Out:
#     Life expectancy   1800   1801   1802   1803  ...  2012  2013  2014  2015   2016
# 255      Yugoslavia    NaN    NaN    NaN    NaN  ...   NaN   NaN   NaN   NaN    NaN
# 256          Zambia  32.60  32.60  32.60  32.60  ...  54.7  55.6  56.3  56.7  57.10
# 257        Zimbabwe  33.70  33.70  33.70  33.70  ...  54.2  55.7  57.0  59.3  61.69
# 258           Åland    NaN    NaN    NaN    NaN  ...   NaN   NaN   NaN   NaN    NaN
# 259     South Sudan  26.67  26.67  26.67  26.67  ...  56.0  56.0  56.1  56.1  56.10
#
# [5 rows x 218 columns]

# %% [markdown]
# When analyzing a dataset, it's always a good idea to start by getting basic information about your dataframe. We can do this by using the `info()` method.

# %%
df_life.columns.values
# Out:
# array(['Life expectancy', '1800', '1801', '1802', '1803', '1804', '1805',
#        '1806', '1807', '1808', '1809', '1810', '1811', '1812', '1813',
#        '1814', '1815', '1816', '1817', '1818', '1819', '1820', '1821',
#        '1822', '1823', '1824', '1825', '1826', '1827', '1828', '1829',
#        '1830', '1831', '1832', '1833', '1834', '1835', '1836', '1837',
#        '1838', '1839', '1840', '1841', '1842', '1843', '1844', '1845',
#        '1846', '1847', '1848', '1849', '1850', '1851', '1852', '1853',
#        '1854', '1855', '1856', '1857', '1858', '1859', '1860', '1861',
#        '1862', '1863', '1864', '1865', '1866', '1867', '1868', '1869',
#        '1870', '1871', '1872', '1873', '1874', '1875', '1876', '1877',
#        '1878', '1879', '1880', '1881', '1882', '1883', '1884', '1885',
#        '1886', '1887', '1888', '1889', '1890', '1891', '1892', '1893',
#        '1894', '1895', '1896', '1897', '1898', '1899', '1900', '1901',
# ...

# %%
print(type(df_life.columns))
print(type(df_life.index))
# Out:
# <class 'pandas.core.indexes.base.Index'>
# <class 'pandas.core.indexes.range.RangeIndex'>

# %%
df_life.shape
# Out:
# (260, 218)

# %%
df_life.drop(list(map(str, range(1800, 1990))), axis=1, inplace=True)
df_life.head(2)
# Out:
#   Life expectancy  1990  1991  1992  1993  ...  2012  2013  2014  2015   2016
# 0        Abkhazia   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN    NaN
# 1     Afghanistan  49.5  49.3  49.4  49.5  ...  54.4  54.8  54.9  53.8  52.72
#
# [2 rows x 28 columns]

# %%
df_life.isnull().sum()
# Out:
# Life expectancy     0
# 1990               52
# 1991               52
# 1992               52
# 1993               52
# 1994               52
# 1995               52
# 1996               52
# 1997               51
# 1998               51
# 1999               51
# 2000               51
# 2001               51
# 2002               51
# 2003               51
# 2004               51
# 2005               51
# 2006               50
# 2007               52
# 2008               52
# 2009               52
# 2010               52
# 2011               52
# 2012               52
# 2013               52
# 2014               52
# 2015               52
# 2016               52
# dtype: int64

# %%
df_life.describe()
# Out:
#              1990        1991        1992  ...        2014       2015        2016
# count  208.000000  208.000000  208.000000  ...  208.000000  208.00000  208.000000
# mean    66.784615   66.844663   67.026875  ...   72.088125   72.32101   72.556635
# std      8.542711    8.521308    8.575423  ...    8.074990    7.90202    7.738535
# min     45.200000   45.400000   45.300000  ...   45.400000   47.10000   48.860000
# 25%     60.925000   60.700000   60.400000  ...   66.775000   67.05000   67.175000
# 50%     69.650000   69.600000   69.450000  ...   74.300000   74.40000   74.500000
# 75%     73.300000   73.427500   73.555000  ...   78.400000   78.50000   78.650000
# max     81.700000   81.800000   81.900000  ...   84.800000   84.80000   84.800000
#
# [8 rows x 27 columns]

# %%
df_life.rename(columns={'Life expectancy':'Country'}, inplace=True)
df_life.columns
# Out:
# Index(['Country', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016'],
#       dtype='object')

# %%
df_life.set_index('Country', inplace=True)
# tip: The opposite of set is reset. So to reset the index, we can use df_can.reset_index()

# %%
df_life.head(3)
# Out:
#                        1990  1991  1992  1993  ...  2013  2014  2015   2016
# Country                                        ...
# Abkhazia                NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN    NaN
# Afghanistan            49.5  49.3  49.4  49.5  ...  54.8  54.9  53.8  52.72
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN    NaN
#
# [3 rows x 27 columns]

# %%
# 1. the full row data (all columns)
print(df_life.loc['Japan'])

# alternate methods
print(df_life.iloc[87])
print(df_life[df_life.index == 'Japan'].T.squeeze())
# Out:
# 1990    79.0
# 1991    79.1
# 1992    79.3
# 1993    79.4
# 1994    79.8
# 1995    79.7
# 1996    80.2
# 1997    80.4
# 1998    80.5
# 1999    80.6
# 2000    81.0
# 2001    81.3
# 2002    81.6
# 2003    81.7
# 2004    81.9
# 2005    82.0
# 2006    82.2
# 2007    82.4
# 2008    82.5
# 2009    82.7
# 2010    82.7
# 2011    82.6
# 2012    82.9
# 2013    83.0
# 2014    83.1
# 2015    83.2
# 2016    83.3
# Name: Japan, dtype: float64
# 1990    69.9
# 1991    70.2
# 1992    70.2
# 1993    70.0
# 1994    70.4
# 1995    70.7
# 1996    70.8
# 1997    70.8
# 1998    70.6
# 1999    70.6
# 2000    70.5
# 2001    70.3
# 2002    70.2
# 2003    70.2
# 2004    69.3
# 2005    70.3
# 2006    70.5
# 2007    70.7
# 2008    70.8
# 2009    70.9
# 2010    71.0
# 2011    71.0
# 2012    71.1
# 2013    71.2
# 2014    71.4
# 2015    71.5
# 2016    71.6
# Name: Grenada, dtype: float64
# 1990    79.0
# 1991    79.1
# 1992    79.3
# 1993    79.4
# 1994    79.8
# 1995    79.7
# 1996    80.2
# 1997    80.4
# ...

# %%
# useful for plotting later on
years = list(map(str, range(1990, 2017)))
years
# Out:
# ['1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016']

# %%
print('data dimensions:', df_life.shape)
print(df_life.columns)
df_life.head(2)
# Out:
# data dimensions: (260, 27)
# Index(['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016'],
#       dtype='object')
#              1990  1991  1992  1993  1994  ...  2012  2013  2014  2015   2016
# Country                                    ...
# Abkhazia      NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN    NaN
# Afghanistan  49.5  49.3  49.4  49.5  48.9  ...  54.4  54.8  54.9  53.8  52.72
#
# [2 rows x 27 columns]

# %% [markdown]
# ---
# # Visualizing Data using Matplotlib<a id="8"></a>

# %%
# we are using the inline backend
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# # Line Pots (Series/Dataframe) <a id="12"></a>

# %%
japan = df_life.loc['Japan', years] # passing in years 1990 - 2016
japan.head()
# Out:
# 1990    79.0
# 1991    79.1
# 1992    79.3
# 1993    79.4
# 1994    79.8
# Name: Japan, dtype: float64

# %%
japan.plot()

# %%
japan.index = japan.index.map(int) # let's change the index values of Japan to type integer for plotting
japan.plot(kind='line')

plt.title('Life Expectancy from Japan')
plt.ylabel('Number of Expectancy')
plt.xlabel('Years')

plt.show() # need this line to show the updates made to the figure

# %%
japan.plot(kind='line')

plt.title('Life Expectancy from Japan')
plt.ylabel('Number of Expectancy')
plt.xlabel('Years')

plt.show()

# %%
df_JS = df_can.loc[['Japan', 'South Korea'], years]
df_JS.head()
# Out:
#              1990  1991  1992  1993  1994  ...  2012  2013  2014  2015  2016
# Japan        79.0  79.1  79.3  79.4  79.8  ...  82.9  83.0  83.1  83.2  83.3
# South Korea  71.8  72.2  72.7  73.1  73.6  ...  80.7  80.9  80.9  81.0  81.1
#
# [2 rows x 27 columns]

# %%
df_JS.plot()

# Config to look right
# plt.figure(figsize=(20,5))
# plt.plot(df_CI.loc['China'], 'r', df_CI.loc['India'], 'b')

plt.title('Life Expectancy from Japan and South Korea')
plt.ylabel('Number of Expectancy')
plt.xlabel('Years')

plt.show()

# %%
df_JS = df_JS.transpose()
df_JS.head()
# Out:
#       Japan  South Korea
# 1990   79.0         71.8
# 1991   79.1         72.2
# 1992   79.3         72.7
# 1993   79.4         73.1
# 1994   79.8         73.6

# %%
df_JS.index = df_JS.index.map(int)
df_JS.plot()

plt.title('Life Expectancy from Japan and South Korea')
plt.ylabel('Number of Expectancies')
plt.xlabel('Years')

plt.show()
